# %% [markdown]
# <a href="https://colab.research.google.com/github/ForwardslashJP/LGMVIP_Task1/blob/main/Pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name**: Pratiksha Prakash Jadhav
#
# **Email**: pratikshajadhav6008@gmail.com
#
# **Task5**: Image to Pencil Sketch with Python
# **@LetsGrowMore (VIP)**
#
# **Role**: Data Science Intern (Feb-2023)

# %% [markdown]
# # **Contents:**
#
# ###     1. Importing Essential Libraries
# ###     2. Read the Image
# ###    3. Converting image into Gray Scale
# ###    4. Inverting image
# ###     5. Bluring the Image
# ###    6. Final Sketch

# %% [markdown]
# # Importing Essential Libraries

# %%
import cv2

# %%
from  google.colab.patches import cv2_imshow

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read The Image

# %%
img=cv2.imread("/content/drive/MyDrive/Dataset/Statue.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=620x413 at 0x7FBF3C6D2E20>

# %% [markdown]
# # Converting image into Gray Scale

# %%
gray_scale_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_img)
# Out:
# <PIL.Image.Image image mode=L size=620x413 at 0x7FBF3C6D2040>

# %% [markdown]
# # Inverting image

# %%
inverted_img=cv2.bitwise_not(gray_scale_img)
cv2_imshow(inverted_img)
# Out:
# <PIL.Image.Image image mode=L size=620x413 at 0x7FBF3C6D2520>

# %% [markdown]
# # Bluring the Image

# %%
img_smoothing=cv2.GaussianBlur(inverted_img, (21 ,21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=620x413 at 0x7FBF5C4E5370>

# %% [markdown]
# # Fianl Sketch

# %%
def dodgeV2(x,y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img=dodgeV2(gray_scale_img , img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=620x413 at 0x7FBF3C6D29D0>

# %% [markdown]
# # **THANK YOU**
